# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
len(df)
# Out:
# 42650

# %%
df.head(5)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='object')

# %%
df.columns = ['date', 'hometeam', 'awayteam', 'homescore', 'awayscore',
       'tournament', 'city', 'country', 'neutral']

# %%
df.head(5)
# Out:
#          date  hometeam  awayteam  homescore  awayscore tournament     city  \
# 0  1872-11-30  Scotland   England          0          0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland          4          2   Friendly   London
# 2  1874-03-07  Scotland   England          2          1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland          2          2   Friendly   London
# 4  1876-03-04  Scotland   England          3          0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
len(df.tournament.unique())
# Out:
# 120

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date          datetime64[ns]
# hometeam              object
# awayteam              object
# homescore              int64
# awayscore              int64
# tournament            object
# city                  object
# country               object
# neutral                 bool
# dtype: object

# %%
df.groupby(["date"]).count()
# Out:
#             hometeam  awayteam  homescore  awayscore  tournament  city  \
# date
# 1872-11-30         1         1          1          1           1     1
# 1873-03-08         1         1          1          1           1     1
# 1874-03-07         1         1          1          1           1     1
# 1875-03-06         1         1          1          1           1     1
# 1876-03-04         1         1          1          1           1     1
# ...              ...       ...        ...        ...         ...   ...
# 2021-09-05        23        23         23         23          23    23
# 2021-09-06         6         6          6          6           6     6
# 2021-09-07        33        33         33         33          33    33
# 2021-09-08        15        15         15         15          15    15
# 2021-09-09         5         5          5          5           5     5
#
#             country  neutral
# date
# 1872-11-30        1        1
# 1873-03-08        1        1
# 1874-03-07        1        1
# 1875-03-06        1        1
# 1876-03-04        1        1
# ...             ...      ...
# 2021-09-05       23       23
# 2021-09-06        6        6
# 2021-09-07       33       33
# 2021-09-08       15       15
# 2021-09-09        5        5
#
# [15341 rows x 8 columns]

# %%
df.groupby(["hometeam"]).count()
# Out:
#                date  awayteam  homescore  awayscore  tournament  city  \
# hometeam
# Abkhazia         18        18         18         18          18    18
# Afghanistan      41        41         41         41          41    41
# Albania         182       182        182        182         182   182
# Alderney          7         7          7          7           7     7
# Algeria         297       297        297        297         297   297
# ...             ...       ...        ...        ...         ...   ...
# Yugoslavia      190       190        190        190         190   190
# Zambia          308       308        308        308         308   308
# Zanzibar         58        58         58         58          58    58
# Zimbabwe        193       193        193        193         193   193
# Åland Islands    27        27         27         27          27    27
#
#                country  neutral
# hometeam
# Abkhazia            18       18
# Afghanistan         41       41
# Albania            182      182
# Alderney             7        7
# Algeria            297      297
# ...                ...      ...
# Yugoslavia         190      190
# Zambia             308      308
# Zanzibar            58       58
# Zimbabwe           193      193
# Åland Islands       27       27
#
# [308 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# %%
neutral = df.neutral.values

# %%
plt.pie(neutral)
plt.show()

# %%
df.hometeam.unique
